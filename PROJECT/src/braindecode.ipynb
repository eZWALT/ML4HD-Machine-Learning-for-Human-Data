# %% [markdown]
# # Braindecode
#
# In this brief tutorial we will show how to use the main EEG libraries (MNE, Braindecode) for benchmarking or exploratory purposes (test models on the target dataset). This can alleviate the burden on the exploration of models thanks to the already pretrained state of the art models found in the literature.

# %%
import mne 
import numpy as np 
from braindecode.models.util import models_dict

from skorch.dataset import ValidSplit
from braindecode import EEGClassifier
from skorch.callbacks import EpochScoring

import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Loading & Format
#
# Firstly we need to understand the data format of EEG signals, which follow a nomenclature known as the **10-20 system**, composed by identifying region (characters) and either a number or a ending Z, following regex: **^(Fp|F|C|P|O|T|AF|FC|CP|PO|FT|TP)([1-9][0-9]*|z)$**
#
# 1) Characters: Fp (Frontopolar), F (Frontal), C (Central), P (Parietal), T (Temporal), O (Occipital).
# 2) Number: Indicates the horizontal position (X-axis) with **odd num -> Left hemisphere**, **even num -> Right Hemisphere**.
# 3) Ending "z": Indicates an special position at the midline of the skull. (Fz, Cz...)

# %%
n_outputs = 4
sfreq = 256
duration = 4
ch_types = "eeg"
n_epochs = 250
ch_names = [
    'Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 
    'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 
    'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2', 'AFz', 'CPz', 'Iz'
]
n_channels = len(ch_names)

# 1. DEFINING METADATA (The "Header")
# This object holds the hardware specifications.
# ch_names: The specific electrode locations (Standard 10-20 system).
# sfreq: Sampling Frequency (Hz). 256 Hz means we record 256 data points per second.
info = mne.create_info(
    ch_names=ch_names, 
    sfreq=sfreq, 
    ch_types=ch_types
)

# 2. GENERATING DATA (The "Signal")
# We create a 3D NumPy array representing the raw electrical potential.
# The shape must strictly follow: (n_epochs, n_channels, n_times)
#   - 100 Epochs:   100 distinct trials/events (e.g., 100 imagined movements).
#   - 3 Channels:   The spatial dimension (C3, C4, Cz).
#   - 1024 Samples: The temporal dimension. 
#                   Calculation: 4 seconds * 256 Hz = 1024 time points.
X = np.random.randn(n_epochs, n_channels, duration * sfreq)

# 3. CREATING THE CONTAINER (The MNE Object)
# EpochsArray binds the raw data (X) with the metadata (info).
# This provides access to built-in signal processing methods (filtering, plotting).
epochs = mne.EpochsArray(X, info=info)

# 4. TARGET LABELS
# The classification targets for the 100 trials.
# Classes: 0, 1, 2, 3 (e.g., Left, Right, Tongue, Passive).
y = np.random.randint(0, n_outputs, size=n_epochs)

# 5. INSPECTION
print(epochs)
# Output will confirm: "100 events (all good), 0 - 3.99 sec, 3 ch"
# Out:
# Not setting metadata
# 250 matching events found
# No baseline correction applied
# 0 projection items activated
# <EpochsArray | 250 events (all good), 0 – 3.996 s (baseline off), ~62.5 MiB, data loaded,
#  '1': 250>

# %% [markdown]
# ## Modelling
#
# Braindecode provides a Pytorch environment using Skorch for providing an scikit-learn compatible interface, providing models for **3 different objectives (Regression, Classification, Embeddings)**, and for multiple **uses cases ()**

# %%
print(f"All the Braindecode models:\n{list(models_dict.keys())}")
# Out:
# All the Braindecode models:
# ['ATCNet', 'AttentionBaseNet', 'AttnSleep', 'BDTCN', 'BIOT', 'CTNet', 'ContraWR', 'Deep4Net', 'DeepSleepNet', 'EEGConformer', 'EEGITNet', 'EEGInceptionERP', 'EEGInceptionMI', 'EEGMiner', 'EEGNeX', 'EEGNet', 'EEGSimpleConv', 'EEGTCNet', 'FBCNet', 'FBLightConvNet', 'FBMSNet', 'IFNet', 'Labram', 'MSVTNet', 'SCCNet', 'SPARCNet', 'ShallowFBCSPNet', 'SignalJEPA', 'SignalJEPA_Contextual', 'SignalJEPA_PostLocal', 'SignalJEPA_PreLocal', 'SincShallowNet', 'SleepStagerBlanco2020', 'SleepStagerChambon2018', 'SyncNet', 'TIDNet', 'TSception', 'USleep']

# %%
net = EEGClassifier(
    "ShallowFBCSPNet",
    module__final_conv_length="auto",
    train_split=ValidSplit(0.2),
    max_epochs=100
)
# Epochs is the X data format for EEG

# %%
net.fit(epochs, y)
# Out:
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.4519       0.2600        3.9859  0.3123
#       2        1.3821       0.2600        2.9707  0.2652
#       3        1.4043       0.2600        2.4639  0.2581
#       4        1.4221       0.2600        2.1650  0.2444
#       5        1.4143       0.2600        1.9648  0.2858
#       6        1.4184       0.2600        1.8301  0.2479
#       7        1.3805       0.2600        1.7306  0.2474
#       8        1.3634       0.2600        1.6591  0.2496
#       9        1.3513       0.2400        1.6044  0.2508
#      10        1.3863       0.2400        1.5649  0.2497
#      11        1.3098       0.2600        1.5346  0.2709
#      12        1.3285       0.2600        1.5123  0.2825
#      13        1.3423       0.2600        1.4941  0.2601
#      14        1.3039       0.2200        1.4799  0.2916
#      15        1.2961       0.2200        1.4697  0.2496
#      16        1.2653       0.2200        1.4621  0.2595
#      17        1.3006       0.2400        1.4555  0.2629
#      18        1.2510       0.2400        1.4497  0.2597
#      19        1.2648       0.2400        1.4455  0.2563
#      20        1.2762       0.2000        1.4421  0.2680
#      21        1.2508       0.2000        1.4389  0.2911
#      22        1.2277       0.2200        1.4366  0.2672
#      23        1.2435       0.2400        1.4352  0.2508
#      24        1.2437       0.2600        1.4334  0.2600
#      25        1.1991       0.2200        1.4328  0.2519
#      26        1.1969       0.2200        1.4321  0.2490
#      27        1.2001       0.2000        1.4313  0.2499
#      28        1.2241       0.2000        1.4306  0.2972
#      29        1.2278       0.2000        1.4295  0.3086
#      30        1.1551       0.2000        1.4289  0.2960
#      31        1.1710       0.2000        1.4290  0.2920
#      32        1.1903       0.2000        1.4281  0.3074
#      33        1.1703       0.1800        1.4281  0.3132
#      34        1.1450       0.1800        1.4279  0.3030
#      35        1.1705       0.1800        1.4270  0.3061
#      36        1.1449       0.1800        1.4267  0.2922
#      37        1.1177       0.1800        1.4258  0.2617
#      38        1.0828       0.1800        1.4251  0.3007
#      39        1.0922       0.1800        1.4250  0.2861
#      40        1.0948       0.1800        1.4244  0.2881
#      41        1.0956       0.1600        1.4240  0.2914
#      42        1.0897       0.1800        1.4236  0.2851
#      43        1.1180       0.1600        1.4234  0.2931
#      44        1.0415       0.1800        1.4227  0.2904
#      45        1.0690       0.1600        1.4226  0.2965
#      46        1.0829       0.1800        1.4222  0.2910
#      47        1.0579       0.1600        1.4219  0.2632
#      48        1.0820       0.1600        1.4218  0.2960
#      49        1.0273       0.1600        1.4213  0.2890
#      50        1.0372       0.1600        1.4210  0.2553
#      51        1.0368       0.1800        1.4207  0.2579
#      52        1.0354       0.2000        1.4202  0.2559
#      53        1.0343       0.2000        1.4197  0.2498
#      54        1.0100       0.2200        1.4191  0.2519
#      55        0.9802       0.2200        1.4199  0.2663
#      56        0.9852       0.2200        1.4198  0.2824
#      57        0.9935       0.2200        1.4192  0.2963
#      58        0.9496       0.2200        1.4193  0.2557
#      59        0.9660       0.2200        1.4198  0.2509
#      60        0.9560       0.2200        1.4197  0.2584
#      61        0.9276       0.2200        1.4195  0.2541
#      62        0.9247       0.2200        1.4192  0.2592
#      63        0.9161       0.2200        1.4192  0.2532
#      64        0.9718       0.2200        1.4188  0.2710
#      65        0.9197       0.2200        1.4190  0.2763
#      66        0.9118       0.2200        1.4185  0.2550
#      67        0.9066       0.2200        1.4185  0.2490
#      68        0.9027       0.2200        1.4183  0.2562
#      69        0.9044       0.2400        1.4183  0.2742
#      70        0.9148       0.2400        1.4178  0.3034
#      71        0.9135       0.2400        1.4178  0.3161
#      72        0.8766       0.2400        1.4181  0.3008
#      73        0.8796       0.2400        1.4181  0.3193
#      74        0.8849       0.2400        1.4181  0.2999
#      75        0.8346       0.2400        1.4181  0.2953
#      76        0.8360       0.2400        1.4176  0.2939
#      77        0.8589       0.2400        1.4181  0.2992
#      78        0.8307       0.2400        1.4188  0.2979
#      79        0.8698       0.2400        1.4194  0.2949
#      80        0.8247       0.2400        1.4195  0.2969
#      81        0.7989       0.2400        1.4195  0.3096
#      82        0.8177       0.2400        1.4189  0.2938
#      83        0.8264       0.2400        1.4190  0.2641
#      84        0.8170       0.2400        1.4193  0.2696
#      85        0.8021       0.2400        1.4192  0.2493
#      86        0.7730       0.2400        1.4190  0.2508
#      87        0.7826       0.2400        1.4191  0.2565
#      88        0.7865       0.2400        1.4187  0.2519
#      89        0.7737       0.2600        1.4184  0.2500
#      90        0.7771       0.2400        1.4178  0.2631
#      91        0.7735       0.2600        1.4182  0.2546
#      92        0.7512       0.2600        1.4185  0.2754
#      93        0.7601       0.2400        1.4183  0.2829
#      94        0.7553       0.2400        1.4184  0.2521
#      95        0.7302       0.2400        1.4189  0.2528
#      96        0.7054       0.2400        1.4190  0.2705
#      97        0.7350       0.2400        1.4190  0.2818
#      98        0.7157       0.2400        1.4195  0.2808
#      99        0.7180       0.2600        1.4202  0.3015
#     100        0.7238       0.2800        1.4209  0.2602
# <class 'braindecode.classifier.EEGClassifier'>[initialized](
#   module_==================================================================================================================================================
#   Layer (type (var_name):depth-idx)             Input Shape               Output Shape              Param #                   Kernel Shape
#   =================================================================================================================================================
#   ShallowFBCSPNet (ShallowFBCSPNet)             [1, 32, 1024]             [1, 4]                    --                        --
#   ├─Ensure4d (ensuredims): 1-1                  [1, 32, 1024]             [1, 32, 1024, 1]          --                        --
#   ├─Rearrange (dimshuffle): 1-2                 [1, 32, 1024, 1]          [1, 1, 1024, 32]          --                        --
#   ├─CombinedConv (conv_time_spat): 1-3          [1, 1, 1024, 32]          [1, 40, 1000, 1]          52,240                    --
#   ├─BatchNorm2d (bnorm): 1-4                    [1, 40, 1000, 1]          [1, 40, 1000, 1]          80                        --
#   ├─Expression (conv_nonlin_exp): 1-5           [1, 40, 1000, 1]          [1, 40, 1000, 1]          --                        --
#   ├─AvgPool2d (pool): 1-6                       [1, 40, 1000, 1]          [1, 40, 62, 1]            --                        [75, 1]
#   ├─SafeLog (pool_nonlin_exp): 1-7              [1, 40, 62, 1]            [1, 40, 62, 1]            --                        --
#   ├─Dropout (drop): 1-8                         [1, 40, 62, 1]            [1, 40, 62, 1]            --                        --
#   ├─Sequential (final_layer): 1-9               [1, 40, 62, 1]            [1, 4]                    --                        --
#   │    └─Conv2d (conv_classifier): 2-1          [1, 40, 62, 1]            [1, 4, 1, 1]              9,924                     [62, 1]
#   │    └─SqueezeFinalOutput (squeeze): 2-2      [1, 4, 1, 1]              [1, 4]                    --                        --
#   │    │    └─Rearrange (squeeze): 3-1          [1, 4, 1, 1]              [1, 4, 1]                 --                        --
#   =================================================================================================================================================
#   Total params: 62,244
#   Trainable params: 62,244
#   Non-trainable params: 0
#   Total mult-adds (Units.MEGABYTES): 0.01
#   =================================================================================================================================================
#   Input size (MB): 0.13
#   Forward/backward pass size (MB): 0.32
#   Params size (MB): 0.04
#   Estimated Total Size (MB): 0.49
#   =================================================================================================================================================,
# )

# %%
print(net.module_)

# %% [markdown]
# Or use the equivalent model nomenclature

# %%
import torch
from braindecode.models import ShallowFBCSPNet
from braindecode.util import set_random_seeds
print(ShallowFBCSPNet.__doc__)

# %%
model = ShallowFBCSPNet(
    n_chans=32,
    n_times=1000,
    n_outputs=2,
    final_conv_length="auto",
)
print(model)

# %% [markdown]
# ## Preprocessing

# %%
# LOAD THE DATA
"""
from numpy import multiply

from braindecode.preprocessing import (
    Preprocessor,
    exponential_moving_standardize,
    preprocess,
)

low_cut_hz = 4.0  # low cut frequency for filtering
high_cut_hz = 38.0  # high cut frequency for filtering
# Parameters for exponential moving standardization
factor_new = 1e-3
init_block_size = 1000
# Factor to convert from V to uV
factor = 1e6

preprocessors = [
    Preprocessor("pick_types", eeg=True, meg=False, stim=False),
    # Keep EEG sensors
    Preprocessor(lambda data: multiply(data, factor)),  # Convert from V to uV
    Preprocessor("filter", l_freq=low_cut_hz, h_freq=high_cut_hz),
    # Bandpass filter
    Preprocessor(
        exponential_moving_standardize,
        # Exponential moving standardization
        factor_new=factor_new,
        init_block_size=init_block_size,
    ),
]

# Transform the data
preprocess(dataset, preprocessors, n_jobs=-1)
"""

# %% [markdown]
# ## Benchmarking different models

# %%
from braindecode.models import EEGConformer, EEGInceptionMI, EEGNeX, EEGNetv4
from braindecode.models import ATCNet
from braindecode.util import set_random_seeds

eeg_net = EEGNetv4(
    # Basic 
    n_outputs=n_outputs,
    n_chans=n_channels,
    n_times=duration * sfreq,
    sfreq=sfreq,
    # Hyperparameters
)

eeg_inception = EEGInceptionMI(
    # Basic 
    n_outputs=n_outputs,
    n_chans=n_channels,
    n_times=duration * sfreq,
    sfreq=sfreq
    # Hyperparameters

)

eeg_nex = EEGNeX(
    # Basic 
    n_outputs=n_outputs,
    n_chans=n_channels,
    n_times=duration * sfreq,
    sfreq=sfreq,
    # Hyperparameters,
)

# 1. Convolution + Lightweight transformer 
eeg_conformer = EEGConformer(
    # Basic 
    n_outputs=n_outputs,
    n_chans=n_channels,
    n_times=duration * sfreq,
    sfreq=sfreq,
    # Hyperparameters (Dropout, attention, convolution)
    n_filters_time=40,
    filter_time_length=25, 
    drop_prob=0.5,
    pool_time_length=75, 
    pool_time_stride=15,
    att_depth=6, 
    att_heads=16,
    att_drop_prob=0.5,
    final_fc_length="auto"
)


atc = ATCNet(
    # Basic 
    n_outputs=n_outputs,
    n_chans=n_channels,
    n_times=duration * sfreq,
    sfreq=sfreq
)

models = [eeg_net, eeg_inception, eeg_nex, eeg_conformer, atc]

cuda = torch.cuda.is_available()
device = "cuda" if cuda else "cpu"
if cuda:
    torch.backends.cudnn.benchmark = True

# Setting a random seed
seed = 42
set_random_seeds(seed=seed, cuda=cuda)
if cuda:
    for model in models:
        model.cuda()
# Out:
# <decorator-gen-500>:4: FutureWarning: NOTE: EEGNetv4() is a deprecated class. `EEGNetv4` was renamed to `EEGNet` in v1.12; this alias will be removed in v1.14..

# %%
batch_size = 16
n_epochs = 10
optimizer_lr = 1e-5
optimizer_weight_decay = 1e-5


# We need to explicitly tell it to calculate 'accuracy' on the training set
# so we can plot it later. Skorch only does validation accuracy by default.
train_acc_callback = EpochScoring(
    scoring='accuracy', 
    on_train=True, 
    name='train_acc', 
    lower_is_better=False
)

classifier = EEGClassifier(
    eeg_conformer,
    batch_size=batch_size,
    max_epochs=n_epochs,
    optimizer__lr=optimizer_lr,
    optimizer__weight_decay=optimizer_weight_decay,
    callbacks=[train_acc_callback],
    #criterion= 
    device='cuda' if torch.cuda.is_available() else 'cpu'
    
)
classifier.fit(epochs, y)
# Out:
#   epoch    train_acc    train_loss    valid_acc    valid_loss     dur
# -------  -----------  ------------  -----------  ------------  ------
#       1       0.2396        1.4476       0.2200        1.4356  4.0421
#       2       0.2396        1.4289       0.2200        1.4331  3.8635
#       3       0.2917        1.4519       0.2200        1.4323  3.8804
#       4       0.2240        1.4291       0.2200        1.4319  3.8519
#       5       0.2292        1.4323       0.2200        1.4318  3.9422
#       6       0.2240        1.4316       0.2200        1.4315  3.9111
#       7       0.1875        1.4534       0.2200        1.4315  3.8774
#       8       0.2344        1.4405       0.2200        1.4313  3.8628
#       9       0.1615        1.4450       0.2200        1.4311  3.8863
#      10       0.2396        1.4299       0.2200        1.4310  3.7370
# <class 'braindecode.classifier.EEGClassifier'>[initialized](
#   module_===========================================================================================================================================================================
#   Layer (type (var_name):depth-idx)                                      Input Shape               Output Shape              Param #                   Kernel Shape
#   ==========================================================================================================================================================================
#   EEGConformer (EEGConformer)                                            [1, 32, 1024]             [1, 4]                    --                        --
#   ├─_PatchEmbedding (patch_embedding): 1-1                               [1, 1, 32, 1024]          [1, 62, 40]               --                        --
#   │    └─Sequential (shallownet): 2-1                                    [1, 1, 32, 1024]          [1, 40, 1, 62]            --                        --
#   │    │    └─Conv2d (0): 3-1                                            [1, 1, 32, 1024]          [1, 40, 32, 1000]         1,040                     [1, 25]
#   │    │    └─Conv2d (1): 3-2                                            [1, 40, 32, 1000]         [1, 40, 1, 1000]          51,240                    [32, 1]
#   │    │    └─BatchNorm2d (2): 3-3                                       [1, 40, 1, 1000]          [1, 40, 1, 1000]          80                        --
#   │    │    └─ELU (3): 3-4                                               [1, 40, 1, 1000]          [1, 40, 1, 1000]          --                        --
#   │    │    └─AvgPool2d (4): 3-5                                         [1, 40, 1, 1000]          [1, 40, 1, 62]            --                        [1, 75]
#   │    │    └─Dropout (5): 3-6                                           [1, 40, 1, 62]            [1, 40, 1, 62]            --                        --
#   │    └─Sequential (projection): 2-2                                    [1, 40, 1, 62]            [1, 62, 40]               --                        --
#   │    │    └─Conv2d (0): 3-7                                            [1, 40, 1, 62]            [1, 40, 1, 62]            1,640                     [1, 1]
#   │    │    └─Rearrange (1): 3-8                                         [1, 40, 1, 62]            [1, 62, 40]               --                        --
#   ├─_TransformerEncoder (transformer): 1-2                               [1, 62, 40]               [1, 62, 40]               --                        --
#   │    └─_TransformerEncoderBlock (0): 2-3                               [1, 62, 40]               [1, 62, 40]               --                        --
#   │    │    └─_ResidualAdd (0): 3-9                                      [1, 62, 40]               [1, 62, 40]               6,640                     --
#   │    │    └─_ResidualAdd (1): 3-10                                     [1, 62, 40]               [1, 62, 40]               13,080                    --
#   │    └─_TransformerEncoderBlock (1): 2-4                               [1, 62, 40]               [1, 62, 40]               --                        --
#   │    │    └─_ResidualAdd (0): 3-11                                     [1, 62, 40]               [1, 62, 40]               6,640                     --
#   │    │    └─_ResidualAdd (1): 3-12                                     [1, 62, 40]               [1, 62, 40]               13,080                    --
#   │    └─_TransformerEncoderBlock (2): 2-5                               [1, 62, 40]               [1, 62, 40]               --                        --
#   │    │    └─_ResidualAdd (0): 3-13                                     [1, 62, 40]               [1, 62, 40]               6,640                     --
#   │    │    └─_ResidualAdd (1): 3-14                                     [1, 62, 40]               [1, 62, 40]               13,080                    --
#   │    └─_TransformerEncoderBlock (3): 2-6                               [1, 62, 40]               [1, 62, 40]               --                        --
#   │    │    └─_ResidualAdd (0): 3-15                                     [1, 62, 40]               [1, 62, 40]               6,640                     --
#   │    │    └─_ResidualAdd (1): 3-16                                     [1, 62, 40]               [1, 62, 40]               13,080                    --
#   │    └─_TransformerEncoderBlock (4): 2-7                               [1, 62, 40]               [1, 62, 40]               --                        --
#   │    │    └─_ResidualAdd (0): 3-17                                     [1, 62, 40]               [1, 62, 40]               6,640                     --
#   │    │    └─_ResidualAdd (1): 3-18                                     [1, 62, 40]               [1, 62, 40]               13,080                    --
#   │    └─_TransformerEncoderBlock (5): 2-8                               [1, 62, 40]               [1, 62, 40]               --                        --
#   │    │    └─_ResidualAdd (0): 3-19                                     [1, 62, 40]               [1, 62, 40]               6,640                     --
#   │    │    └─_ResidualAdd (1): 3-20                                     [1, 62, 40]               [1, 62, 40]               13,080                    --
#   ├─_FullyConnected (fc): 1-3                                            [1, 62, 40]               [1, 32]                   --                        --
#   │    └─Sequential (fc): 2-9                                            [1, 2480]                 [1, 32]                   --                        --
#   │    │    └─Linear (0): 3-21                                           [1, 2480]                 [1, 256]                  635,136                   --
#   │    │    └─ELU (1): 3-22                                              [1, 256]                  [1, 256]                  --                        --
#   │    │    └─Dropout (2): 3-23                                          [1, 256]                  [1, 256]                  --                        --
#   │    │    └─Linear (3): 3-24                                           [1, 256]                  [1, 32]                   8,224                     --
#   │    │    └─ELU (4): 3-25                                              [1, 32]                   [1, 32]                   --                        --
#   │    │    └─Dropout (5): 3-26                                          [1, 32]                   [1, 32]                   --                        --
#   ├─Linear (final_layer): 1-4                                            [1, 32]                   [1, 4]                    132                       --
#   ==========================================================================================================================================================================
#   Total params: 815,812
#   Trainable params: 815,812
#   Non-trainable params: 0
#   Total mult-adds (Units.MEGABYTES): 85.38
#   ==========================================================================================================================================================================
#   Input size (MB): 0.13
#   Forward/backward pass size (MB): 12.21
#   Params size (MB): 3.26
#   Estimated Total Size (MB): 15.61
#   ==========================================================================================================================================================================,
# )

# %%
# --- 3. PLOT (ADAPTED FOR CLASSIFICATION) ---
# We retrieve the history directly from the classifier object
h = classifier.history

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Plot 1: Loss (Cross Entropy)
axes[0].set_title("Loss Curve (Lower is Better)")
axes[0].plot(h[:, "train_loss"], label="Train Loss", linewidth=2)
axes[0].plot(h[:, "valid_loss"], label="Valid Loss", linewidth=2, linestyle='--')
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Cross Entropy Loss")
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# Plot 2: Accuracy (Class correct %)
axes[1].set_title("Accuracy Curve (Higher is Better)")
axes[1].plot(h[:, "train_acc"], label="Train Acc", linewidth=2, color='green')
axes[1].plot(h[:, "valid_acc"], label="Valid Acc", linewidth=2, linestyle='--', color='orange')
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("Accuracy")
axes[1].grid(True, alpha=0.3)
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Using our Dataset
